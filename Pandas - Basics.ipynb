# %%
import pandas as pd

# %% [markdown]
# #### Series
#
# * Similar to array but have index attached to it (Sequence)
# * (array,list,tuple,dictionary)

# %%
list = ["Umang","machine","learning","python","AI"]
pd.Series(list)
# Out:
# 0       Umang
# 1     machine
# 2    learning
# 3      python
# 4          AI
# dtype: object

# %%
tuple = ("Umang","machine","learning","python","AI")
pd.Series(tuple)
# Out:
# 0       Umang
# 1     machine
# 2    learning
# 3      python
# 4          AI
# dtype: object

# %%
tuple = ("Umang","machine","learning","python","AI")
ind = ("A","B","C","D","E")
pd.Series(tuple,index=ind)
# Out:
# A       Umang
# B     machine
# C    learning
# D      python
# E          AI
# dtype: object

# %%
dict = {"A":"Umang","B":"Machine","C":"Learning","D":"Python"}
pd.Series(dict)
# Out:
# A       Umang
# B     Machine
# C    Learning
# D      Python
# dtype: object

# %%
dict = {"A":"Umang","B":"Machine","C":"Learning","D":"Python"}
s = pd.Series(dict)

# %%
s.index
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
s.values
# Out:
# array(['Umang', 'Machine', 'Learning', 'Python'], dtype=object)

# %%
s.dtype
# Out:
# dtype('O')

# %%
s.head(2)
# Out:
# A      Umang
# B    Machine
# dtype: object

# %%
s.tail(2)
# Out:
# C    Learning
# D      Python
# dtype: object

# %%
s[:]
# Out:
# A       Umang
# B     Machine
# C    Learning
# D      Python
# dtype: object

# %%
s[1:2]
# Out:
# B    Machine
# dtype: object

# %%
s[1:3]
# Out:
# B     Machine
# C    Learning
# dtype: object

# %%
s["B":"D"]
# Out:
# B     Machine
# C    Learning
# D      Python
# dtype: object

# %%
marks = [90,70,50]
sub = ["Maths","Science","SST"]
s1 = pd.Series(marks,index=sub)
s1
# Out:
# Maths      90
# Science    70
# SST        50
# dtype: int64

# %%
marks = [100,80,30]
sub = ["Maths","Science","SST"]
s2 = pd.Series(marks,index=sub)
s2
# Out:
# Maths      100
# Science     80
# SST         30
# dtype: int64

# %%
s1+s2
# Out:
# Maths      190
# Science    150
# SST         80
# dtype: int64

# %%
marks = [60,90,100]
sub = ["Science","SST","Maths"]
s3 = pd.Series(marks,index=sub)
s3
# Out:
# Science     60
# SST         90
# Maths      100
# dtype: int64

# %%
s1
# Out:
# Maths      90
# Science    70
# SST        50
# dtype: int64

# %%
s1+s3
# Out:
# Maths      190
# SST        140
# Science    130
# dtype: int64

# %%
data = pd.read_csv(r'C:\Users\umang\Desktop\abc.csv',
                   usecols=["Names"],squeeze=True)

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data.head(2)
# Out:
# 0    Umang
# 1    Rohan
# Name: Names, dtype: object

# %%
data.sort_values()
# Out:
# 3    Aakash
# 2       Raj
# 4      Ravi
# 1     Rohan
# 0     Umang
# Name: Names, dtype: object

# %%
data.sort_values(ascending=False)
# Out:
# 0     Umang
# 1     Rohan
# 4      Ravi
# 2       Raj
# 3    Aakash
# Name: Names, dtype: object

# %%
data = data.sort_values(ascending=False)

# %%
data
# Out:
# 0     Umang
# 1     Rohan
# 4      Ravi
# 2       Raj
# 3    Aakash
# Name: Names, dtype: object

# %% [markdown]
# ### Data Frames

# %%
import pandas as pd
import numpy as np
from numpy.random import randn
np.random.seed(100)
df = pd.DataFrame(randn(5,5),["A","B","C","D","E"],
                  ["Col 1","Col 2","Col 3","Col 4","Col 5"])
df
# Out:
#       Col 1     Col 2     Col 3     Col 4     Col 5
# A -1.749765  0.342680  1.153036 -0.252436  0.981321
# B  0.514219  0.221180 -1.070043 -0.189496  0.255001
# C -0.458027  0.435163 -0.583595  0.816847  0.672721
# D -0.104411 -0.531280  1.029733 -0.438136 -1.118318
# E  1.618982  1.541605 -0.251879 -0.842436  0.184519

# %%
df["Col 1"]
# Out:
# A   -1.749765
# B    0.514219
# C   -0.458027
# D   -0.104411
# E    1.618982
# Name: Col 1, dtype: float64

# %%
type(df["Col 1"])
# Out:
# pandas.core.series.Series

# %%
df[["Col 1"]]
# Out:
#       Col 1
# A -1.749765
# B  0.514219
# C -0.458027
# D -0.104411
# E  1.618982

# %%
type(df[["Col 1"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Col 1","Col 2","Col 5"]]
# Out:
#       Col 1     Col 2     Col 5
# A -1.749765  0.342680  0.981321
# B  0.514219  0.221180  0.255001
# C -0.458027  0.435163  0.672721
# D -0.104411 -0.531280 -1.118318
# E  1.618982  1.541605  0.184519

# %%
df.head(2)
# Out:
#       Col 1    Col 2     Col 3     Col 4     Col 5
# A -1.749765  0.34268  1.153036 -0.252436  0.981321
# B  0.514219  0.22118 -1.070043 -0.189496  0.255001

# %%
df.tail(2)
# Out:
#       Col 1     Col 2     Col 3     Col 4     Col 5
# D -0.104411 -0.531280  1.029733 -0.438136 -1.118318
# E  1.618982  1.541605 -0.251879 -0.842436  0.184519

# %%
df.isnull().any()
# Out:
# Col 1    False
# Col 2    False
# Col 3    False
# Col 4    False
# Col 5    False
# dtype: bool

# %%
df.isnull()
# Out:
#    Col 1  Col 2  Col 3  Col 4  Col 5
# A  False  False  False  False  False
# B  False  False  False  False  False
# C  False  False  False  False  False
# D  False  False  False  False  False
# E  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# Col 1    0
# Col 2    0
# Col 3    0
# Col 4    0
# Col 5    0
# dtype: int64

# %%
df.drop("Col 3",axis=1,inplace=True)

# %%
df
# Out:
#       Col 1     Col 2     Col 4     Col 5
# A -1.749765  0.342680 -0.252436  0.981321
# B  0.514219  0.221180 -0.189496  0.255001
# C -0.458027  0.435163  0.816847  0.672721
# D -0.104411 -0.531280 -0.438136 -1.118318
# E  1.618982  1.541605 -0.842436  0.184519

# %%
df.drop("C",axis=0,inplace=True)

# %%
df
# Out:
#       Col 1     Col 2     Col 4     Col 5
# A -1.749765  0.342680 -0.252436  0.981321
# B  0.514219  0.221180 -0.189496  0.255001
# D -0.104411 -0.531280 -0.438136 -1.118318
# E  1.618982  1.541605 -0.842436  0.184519

# %%
df.dropna(inplace=True)

# %%
df.fillna(0)
# Out:
#       Col 1     Col 2     Col 4     Col 5
# A -1.749765  0.342680 -0.252436  0.981321
# B  0.514219  0.221180 -0.189496  0.255001
# D -0.104411 -0.531280 -0.438136 -1.118318
# E  1.618982  1.541605 -0.842436  0.184519

# %%
df['Col 2'].fillna(0)
# Out:
# A    0.342680
# B    0.221180
# D   -0.531280
# E    1.541605
# Name: Col 2, dtype: float64

# %%
df['Col 5'] = 20

# %%
df
# Out:
#       Col 1     Col 2     Col 4  Col 5
# A -1.749765  0.342680 -0.252436     20
# B  0.514219  0.221180 -0.189496     20
# D -0.104411 -0.531280 -0.438136     20
# E  1.618982  1.541605 -0.842436     20

# %%
df['Col 6'] = [20,10,30,56]

# %%
df
# Out:
#       Col 1     Col 2     Col 4  Col 5  Col 6
# A -1.749765  0.342680 -0.252436     20     20
# B  0.514219  0.221180 -0.189496     20     10
# D -0.104411 -0.531280 -0.438136     20     30
# E  1.618982  1.541605 -0.842436     20     56

# %%
df.rename(columns={"Col 1":"Column 1","Col 4":"Column 5"},inplace=True)

# %%
df
# Out:
#    Column 1     Col 2  Column 5  Col 5  Col 6
# A -1.749765  0.342680 -0.252436     20     20
# B  0.514219  0.221180 -0.189496     20     10
# D -0.104411 -0.531280 -0.438136     20     30
# E  1.618982  1.541605 -0.842436     20     56

# %% [markdown]
# #### import from csv

# %%
df = pd.read_csv(r'C:\Users\umang\Data Science\Data Sets\nba.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
mean_sal = df['Salary'].mean()

# %%
mean_sal = np.round(mean_sal,2)
mean_sal
# Out:
# 4842684.11

# %%
df['Salary'].fillna(mean_sal,inplace=True)

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College      Salary
# 0              Texas  7730337.00
# 1          Marquette  6796117.00
# 2  Boston University  4842684.11
# 3      Georgia State  1148640.00
# 4                NaN  5000000.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      458 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 456
# Data columns (total 9 columns):
# Name        373 non-null object
# Team        373 non-null object
# Number      373 non-null float64
# Position    373 non-null object
# Age         373 non-null float64
# Height      373 non-null object
# Weight      373 non-null float64
# College     373 non-null object
# Salary      373 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 29.1+ KB

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.index
# Out:
# Int64Index([  0,   1,   2,   3,   6,   7,   8,   9,  10,  11,
#             ...
#             442, 443, 444, 446, 448, 449, 451, 452, 453, 456],
#            dtype='int64', length=373)

# %%
df[["Name","Number","Age"]]
# Out:
#                         Name  Number   Age
# 0              Avery Bradley     0.0  25.0
# 1                Jae Crowder    99.0  25.0
# 2               John Holland    30.0  27.0
# 3                R.J. Hunter    28.0  22.0
# 6              Jordan Mickey    55.0  21.0
# 7               Kelly Olynyk    41.0  25.0
# 8               Terry Rozier    12.0  22.0
# 9               Marcus Smart    36.0  22.0
# 10           Jared Sullinger     7.0  24.0
# 11             Isaiah Thomas     4.0  27.0
# 12               Evan Turner    11.0  27.0
# 13               James Young    13.0  20.0
# 14              Tyler Zeller    44.0  26.0
# 16              Markel Brown    22.0  24.0
# 17           Wayne Ellington    21.0  28.0
# 18   Rondae Hollis-Jefferson    24.0  21.0
# 19              Jarrett Jack     2.0  32.0
# 21           Sean Kilpatrick     6.0  26.0
# 22              Shane Larkin     0.0  23.0
# 23               Brook Lopez    11.0  28.0
# 24          Chris McCullough     1.0  21.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College      Salary
# 0              Texas  7730337.00
# 1          Marquette  6796117.00
# 2  Boston University  4842684.11
# 3      Georgia State  1148640.00
# 6                LSU  1170960.00

# %%
df.sort_values("Salary",ascending=False)
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 33      Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 339          Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# 100          Chris Paul    Los Angeles Clippers     3.0       PG  31.0    6-0
# 414        Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0    6-9
# 164        Derrick Rose           Chicago Bulls     1.0       PG  27.0    6-3
# 349         Dwyane Wade              Miami Heat     3.0       SG  34.0    6-4
# 98       DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0   6-11
# 294   LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0   6-11
# 174          Kevin Love     Cleveland Cavaliers     0.0       PF  27.0   6-10
# 23          Brook Lopez           Brooklyn Nets    11.0        C  28.0    7-0
# 96        Blake Griffin    Los Angeles Clippers    32.0       PF  27.0   6-10
# ...

# %%
df.sort_values("Name",ascending=True)
# Out:
#                     Name                    Team  Number Position   Age  \
# 152         Aaron Brooks           Chicago Bulls     0.0       PG  31.0
# 356         Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 328       Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 404        Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 312           Al Horford           Atlanta Hawks    15.0        C  30.0
# 428      Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 368        Alan Anderson      Washington Wizards     6.0       SG  33.0
# 135        Alan Williams            Phoenix Suns    15.0        C  23.0
# 444           Alec Burks               Utah Jazz    10.0       SG  24.0
# 128             Alex Len            Phoenix Suns    21.0        C  22.0
# 273       Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0
# 430         Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# ...

# %%
df = df.sort_values("Name",ascending=True).reset_index()

# %%
df.head()
# Out:
#    index            Name                    Team  Number Position   Age  \
# 0    152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0
# 1    356    Aaron Gordon           Orlando Magic     0.0       PF  20.0
# 2    328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0
# 3    404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0
# 4    312      Al Horford           Atlanta Hawks    15.0        C  30.0
#
#   Height  Weight         College      Salary
# 0    6-0   161.0          Oregon   2250000.0
# 1    6-9   220.0         Arizona   4171680.0
# 2    6-6   210.0        Kentucky    525093.0
# 3   6-10   237.0  Michigan State   1938840.0
# 4   6-10   245.0         Florida  12000000.0

# %%
df.drop("index",axis=1,inplace=True)

# %%
df.head()
# Out:
#              Name                    Team  Number Position   Age Height  \
# 0    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 1    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 2  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 3   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 4      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
#
#    Weight         College      Salary
# 0   161.0          Oregon   2250000.0
# 1   220.0         Arizona   4171680.0
# 2   210.0        Kentucky    525093.0
# 3   237.0  Michigan State   1938840.0
# 4   245.0         Florida  12000000.0
